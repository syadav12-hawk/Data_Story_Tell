# %% [markdown]
# ## This notebook demos Python data visualizations on the Iris dataset

# %%
#Import Library and Irish dataset
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
#sns.set(color_codes=True)
import warnings
warnings.filterwarnings("ignore")


iris = pd.read_csv("Iris.csv")
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# So, you can see we have 6 columns; the first is just the plant ID, the next 4 are independent variables, and the last column is effectively the dependent variable.

# %%
# Let's see how many examples we have of each species as well as the data type for 
# each species
iris["Species"].value_counts()
# Out:
# Iris-versicolor    50
# Iris-setosa        50
# Iris-virginica     50
# Name: Species, dtype: int64

# %% [markdown]
# ## Check for pattern for different species using Petal and Sepal measures

# %%
# One piece of information missing in the plots above is what species each plant is
sns.FacetGrid(iris, hue="Species", palette="husl", size=5) \
   .map(plt.scatter, "SepalLengthCm", "SepalWidthCm") \
   .add_legend()
plt.show()

# %% [markdown]
# In the graph above, you can see there seems to be a split between portions of the data (data points with large sepal width but lower sepal length seem to be clustered together, for example). Also, there look to be a few potential outliers toward the top right.

# %%
# One piece of information missing in the plots above is what species each plant is
sns.FacetGrid(iris, hue="Species", palette="husl", size=5) \
   .map(plt.scatter, "PetalLengthCm", "PetalWidthCm") \
   .add_legend()
plt.show()

# %% [markdown]
# Hence based on PetalLengh and Petal Width Irish Setosa is clearly differentiable from other species.

# %% [markdown]
# ## Use Boxpot to see if the species are differentiable based on the features.

# %%
# We can look at an individual feature in Seaborn through mnay different kinds of plots. 
# Here's a boxplot
for feat in ["PetalLengthCm","PetalWidthCm","SepalLengthCm","SepalWidthCm"]:
    sns.boxplot(x="Species", y=feat, palette="husl", data=iris)
    plt.show()

# %% [markdown]
# From the boxplot above alone, we can see that each Iris species is clearly separable based upon features.

# %% [markdown]
# ## Check the density of the features using Violin plot

# %%
# Here's a violinplot -- this shows the density of data at each primary split, where 
# denser sections are fatter than more sparse sections
for feat in ["PetalLengthCm","PetalWidthCm","SepalLengthCm","SepalWidthCm"]:
    sns.violinplot(x="Species", y=feat, palette="husl", data=iris)
    plt.show()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# Hence based on different visulization above we see that the species are seprable using the features.
